# %% [markdown]
# # Persistent Variability Metrics

# %% [markdown]
# Daniel Mortlock, Vasiliy Belokurov, Simon Hodgkin, Steven Feeney, Chris Lintott, Phil Marshall
#
# _LSST:UK Cadenece Workshop, Cambridge, May 18-20, 2015_

# %% [markdown]
# ## Example Science Cases
#
# * **Finding z=7 Quasars**: How many z=7 quasars will we find after 1 year of surveying? How well can these objects be characterised? i.e. How pure a sample can we make? z=7 quasars are recognisable by 1) their z-dropout nature (ie zero flux in _ugriz_ and some detection in _y_), 2) their quasar-like variability (ie lightcurves with variability on all scales, and a increasing structure function), and 3) their lack of proper motion.
# * **Finding RR Lyrae**: Likewise, but for RR Lyrae stars, for mapping MW halo structure. RR Lyrae are recognisable by their less-than-one day, highly periodic and in some cases modulated variability, in all bands.
# * **Finding Young Stellar Object (YSO) Bursts**: How well can we characterise the population of young stellar object bursts? Young stars undergo possibly episodic bursts, where their brightness increases rapidly by ~1 mag, before decaying over several weeks. _u_-band variability is particularly interesting. Distinguishing YSO bursts from other transients relies on the presence of a YSO pre-cursor.
# * **Measuring Lensed Quasar Time Delays**: How many lensed quasars will have well-measured time delays? The requirements for accurate cosmology are extreme, but the TDC model allows us to relate the accuracy to three summaries of the observing pattern, night-to-night cadence, season length and campaign length.

# %% [markdown]
# ## Common Ground
#
# Many science projects involve _using LSST as a finder_. In these cases, the main science comes from spectroscopic, multi-wavelength and/or high resolution imaging follow-up of an interesting sample of objects. In these projects, there will be keen interest in following up these new targets very soon after the first data release. Similarly, it is of interest to know how the sample is likely to evolve after 2, 3, years. _We would like to investigate metrics relating to these science cases over the course of the campaign._
#
# The metrics of interest to each group relate to either the detectability or measurability of time-variable objects. As such they are likely to be functions of the `night` or `expMJD` database fields. In each case we expect to have a model of how the objects across the sky, and so knowing the detectability/measurability across the sky should be useful in science planning - so we expect the `healpixSlicer` (with `ditheredRA` and `ditheredDec`) as being most relevant.

# %% [markdown]
# ## Possible Tensions
#
# RR Lyrae potentially benefit from intra-night sampling (ie the solar system visit pairs), while longer timescale variable AGN might benefit from spreading out the visits more.
#
# YSOs and high extinction RR Lyrae need observations in the galactic plane, while quasar searching and measurement might be better focused on the extragalactic sky.

# %% [markdown]
# ## Goals
#
# We identified three goals for the group, with related activities:
#
# #### Get Started with MAF
#
# * Work through the existing variability metrics notebook.
# * Think about how we might want to extend it, with some simple metrics related to the science cases above.
# * Browse the existing metrics to see what we can build from. Of particular relevance is
# [Lynne Jones's rapid revisit work](http://tusken.astro.washington.edu:8080/allMetricResults?runId=1#A:%20Required%20SRD%20metrics_Rapid%20Revisit), the
# [tGaps metric code](https://github.com/lsst/sims_maf/blob/master/python/lsst/sims/maf/metrics/tgaps.py), and the
# [mean night separation metric code](https://github.com/LSST-nonproject/sims_maf_contrib/blob/master/mafContrib/meanNightSeparationMetric.py). We'll also need to be familiar with the [summary table column descriptions](https://confluence.lsstcorp.org/display/SIM/Summary+Table+Column+Descriptions).
# * Code up an interesting but very simple metric bundle.
#
# #### Investigate Survey Build-up
#
# * Produce metric reports for each annual data release, to help set the expectations of those planning "finder" projects
# * (Some existing notebooks may already have examples of how to loop over SQL constraints and organize the outputs.)
#
# #### Compare Survey Strategies
#
# The available OpSim output databases are listed [here](https://confluence.lsstcorp.org/display/SIM/OpSim+Datasets+for+Cadence+Workshop+LSST2015). The baseline strategy is captured in **enigma_1189**. An interesting alternative for persistent variable object science is **opsim1_1160**, which is the same as enigma_1189 _except_ that the requirement of having transit time visit pairs for solar system (asteroid) science has been dropped. One effect should be to improve the sampling for long-timescale AGN at the expense of short-timescale RR Lyrae.
#
# * Compare our chosen metrics between these OpSim runs.

# %% [markdown]
# ## Periodic Variable Metric Analysis

# %% [markdown]
# The Sims team has started developing some variability metrics to begin understanding LSST performance for discovering and characterising periodic variables. This notebook has been adapted from [Variability Metrics.ipynb](https://github.com/LSST-nonproject/sims_maf_contrib/blob/master/other/Variability%20Metrics.ipynb), and uses the metrics in [varMetrics.py](https://github.com/LSST-nonproject/sims_maf_contrib/blob/master/mafContrib/varMetrics.py), all in the [sims_maf_contrib](https://github.com/LSST-nonproject/sims_maf_contrib) github repo.

# %% [markdown]
# #### Periodic Variable Metrics
#
# One metric, `PhaseGaps`, looks at the gaps in phase coverage for a set of observations. At each point in the sky (if we use a healpix slicer), a range of periods and the times of the visits are converted to phase values: then the largest gap in these phases is calculated. The metric calculates the max gap for a range of periods at each point; thus it also provides a few reduce functions to convert this to the period with the largest gap (at each point in the sky) and the value of the largest gap in phase coverage (at each point in the sky). We can also read the metric values back into python and generate plots of phase gaps vs. period, including the data for all points.
#
# A second metric. `PeriodDeviation`, generates a light curve (representing the variability of the source as a simple sine curve but neglecting photometric errors) with user-settable range of periods, then attempts to recover the period using a simple lomb-scargle calculation. Changing the period fitting routine would doubtless improve the period recovery.  Again, this should be paired with a healpix slicer to evaluate sets of visits which correspond to the same spot on the sky, and again each point is sampled at a range of different periods so the metric provides reduce methods and we can also read back in the results to evaluate true period vs. fit period across the entire sky.
#
# (NB. This notebook requires sims_maf version >= 1.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Import MAF modules.
import lsst.sims.maf.db as db
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.plots as plots
from lsst.sims.maf.metricBundles import MetricBundle, MetricBundleGroup
# Import the contributed metrics and stackers 
import mafContrib

# %% [markdown]
# Connect to the opsim database and set up some metadata.

# %%
runName = 'enigma_1189'
dbAddress = 'sqlite:///' + runName + '_sqlite.db'
opsdb = db.OpsimDatabase(dbAddress)
outDir = 'variability_test'

# %%
help(opsdb.queryDatabase)
# Out:
# Help on method queryDatabase in module lsst.sims.maf.db.Database:
#
# queryDatabase(self, tableName, sqlQuery) method of lsst.sims.maf.db.opsimDatabase.OpsimDatabase instance
#     Execute a general sql query (useful for arbitary joins or queries not in convenience functions).
#     At present, 'table' (name) must be specified and all columns returned by query must be part of 'table'.
#     Returns numpy recarray with results.

# %%
print opsdb.tables['Summary'].columns
# Out:
# [('obsHistID', 'obsHistID', <type 'int'>), ('sessionID', 'sessionID', <type 'int'>), ('propID', 'propID', <type 'int'>), ('fieldID', 'fieldID', <type 'int'>), ('fieldRA', 'fieldRA', <type 'float'>), ('fieldDec', 'fieldDec', <type 'float'>), ('filter', 'filter', <type 'str'>, 256), ('expDate', 'expDate', <type 'int'>), ('expMJD', 'expMJD', <type 'float'>), ('night', 'night', <type 'int'>), ('visitTime', 'visitTime', <type 'float'>), ('visitExpTime', 'visitExpTime', <type 'float'>), ('finRank', 'finRank', <type 'float'>), ('finSeeing', 'finSeeing', <type 'float'>), ('transparency', 'transparency', <type 'float'>), ('airmass', 'airmass', <type 'float'>), ('vSkyBright', 'vSkyBright', <type 'float'>), ('filtSkyBrightness', 'filtSkyBrightness', <type 'float'>), ('rotSkyPos', 'rotSkyPos', <type 'float'>), ('lst', 'lst', <type 'float'>), ('altitude', 'altitude', <type 'float'>), ('azimuth', 'azimuth', <type 'float'>), ('dist2Moon', 'dist2Moon', <type 'float'>), ('solarElong', 'solarElong', <
# ...

# %%
print opsdb.tables.keys()
# Out:
# ['Field', 'Seeing', 'MissedHistory', 'SeqHistory_MissedHistory', 'SlewActivities', 'SlewHistory', 'SlewState', 'Summary', 'SeqHistory', 'ObsHistory_Proposal', 'SeqHistory_ObsHistory', 'Session', 'ObsHistory', 'Proposal_Field', 'SlewMaxSpeeds', 'Config', 'Proposal', 'Cloud']

# %% [markdown]
# Set up the metrics and slicer.

# %%
opsdb.queryDatabase(opsdb.Field, "select count(*)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-b348fb1c073e> in <module>()
# ----> 1 opsdb.queryDatabase(opsdb.Field, "select count(*)")
#
# AttributeError: 'OpsimDatabase' object has no attribute 'Field'

# %%
phaseMetric = mafContrib.PhaseGapMetric(nPeriods=20, periodMin=0.2, periodMax=3.5)
periodMetric = mafContrib.PeriodDeviationMetric(nPeriods=2, periodMin=2, periodMax=3.5)
meannightMetric = mafContrib.MeanNightSeparationMetric()
# seasonlengthMetric = mafContrib.SeasonLengthMetric()
phaseslicer = slicers.HealpixSlicer(nside=32, lonCol='ditheredRA', latCol='ditheredDec')
periodslicer = slicers.HealpixSlicer(nside=4, lonCol='ditheredRA', latCol='ditheredDec')
meannightSlicer = slicers.HealpixSlicer(nside=4, lonCol='ditheredRA', latCol='ditheredDec')
# Out:
# Healpix slicer using NSIDE=32, approximate resolution 109.935565 arcminutes
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes

# %%
summaryMetrics = [metrics.MinMetric(), metrics.MaxMetric(), metrics.MeanMetric()]

# %%
sqlconstraint = 'night<730 and night>365 and (filter="r" or filter="i")'
phaseBundle = MetricBundle(phaseMetric, phaseslicer, sqlconstraint=sqlconstraint, 
                           runName=runName, summaryMetrics=summaryMetrics)
periodBundle = MetricBundle(periodMetric, periodslicer, sqlconstraint=sqlconstraint, 
                            runName=runName, summaryMetrics=summaryMetrics)

# %%
bdict = {'Phase':phaseBundle, 'Period':periodBundle}

# %%
resultsDb = db.ResultsDb(outDir=outDir)
bgroup = MetricBundleGroup(bdict, opsdb, outDir=outDir, resultsDb=resultsDb)

# %%
bgroup.runAll()
# Out:
# Querying database with constraint night<730 and night>365 and (filter="r" or filter="i")
# Found 114728 visits
# Running:  ['Phase']
# Completed metric generation.
# Running:  ['Period']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
bgroup.plotAll(closefigs=False)
# Out:
# Plotting.
# monopole: 1.93003  dipole: lon: 168.004, lat: -41.8688, amp: 0.0658206
# monopole: 0.171115  dipole: lon: 7.13956, lat: -79.2612, amp: 0.0620993
# monopole: 0.313355  dipole: lon: 14.3225, lat: -76.1215, amp: 0.0705676
# Cannot plot object metric values with this plotter.
# Cannot plot object metric values with this plotter.
# Cannot plot object metric values with this plotter.
# Optimal bin calculation tried to make 362 bins, returning 200
# monopole: 0.0591536  dipole: lon: -94.393, lat: 36.9846, amp: 0.0593885
# Cannot plot object metric values with this plotter.
# Cannot plot object metric values with this plotter.
# Cannot plot object metric values with this plotter.
# Optimal bin calculation tried to make 627 bins, returning 200
# monopole: 0.0302208  dipole: lon: -65.6727, lat: 51.2447, amp: 0.123483
# monopole: 2.82111  dipole: lon: 55.9019, lat: 74.8175, amp: 0.19413
# Plotting complete.

# %% [markdown]
# Plot a contour plot of the periods vs. phase gaps (counting all points across the sky).
# (We'll add this kind of plot as a plotter option into maf itself, but it just hasn't quite made it there yet.)

# %%
def count_number(x, y, xbinsize=None, ybinsize=None, nxbins=None, nybins=None):
    # Set up grid for contour/density plot.
    xmin = min(x)
    ymin = min(y)
    if (xbinsize!=None) & (ybinsize!=None):
        xbins = np.arange(xmin, max(x), xbinsize)
        ybins = np.arange(ymin, max(y), ybinsize)
        nxbins = xbins.shape[0]
        nybins = ybins.shape[0]
    elif (nxbins!=None) & (nybins!=None):
        xbinsize = (max(x) - xmin)/float(nxbins)
        ybinsize = (max(y) - ymin)/float(nybins)
        xbins = np.arange(xmin, max(x), xbinsize)
        ybins = np.arange(ymin, max(y), ybinsize)
        nxbins = xbins.shape[0]
        nybins = ybins.shape[0]
    else:
        raise Exception("Must specify both of either xbinsize/ybinsize or nxbins/nybins")
    counts = np.zeros((nybins, nxbins), dtype='int')
    # Assign each data point (x/y) to a bin.
    for i in range(len(x)):
        xidx = min(int((x[i] - xmin)/xbinsize), nxbins-1)
        yidx = min(int((y[i] - ymin)/ybinsize), nybins-1)
        counts[yidx][xidx] += 1
    # Create 2D x/y arrays, to match 2D counts array.
    xi, yi = np.meshgrid(xbins, ybins)
    return xi, yi, counts

# %%
nperiods = len(phaseBundle.metricValues[-1:][0]['periods'])
periods = []
phaseGaps = []
for mval in phaseBundle.metricValues.compressed():
    for p, pGap in zip(mval['periods'], mval['maxGaps']):
            periods.append(p)
            phaseGaps.append(pGap)

periods = np.array(periods, 'float')
phaseGaps = np.array(phaseGaps, 'float')
timeGaps = phaseGaps * periods

periodi, phasegapi, counts = count_number(periods, phaseGaps, nxbins=100, nybins=100)
plt.figure()
levels = np.log10(np.arange(0.1, 200, 1))
plt.contourf(periodi, phasegapi, np.log10(counts), levels, extend='max')
cbar = plt.colorbar()
cbar.set_label('logN')
plt.xlabel('Period (days)')
plt.ylabel('Largest Phase gap')
# Out:
# /Users/lynnej/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: RuntimeWarning: divide by zero encountered in log10

# %%
nperiods = len(periodBundle.metricValues[-1:][0]['periods'])
periods = []
periodsdev = []
for mval in periodBundle.metricValues.compressed():
    for p, pdev in zip(mval['periods'], mval['periodsdev']):
            periods.append(p)
            periodsdev.append(pdev)

periods = np.array(periods, 'float')
periodsdev = np.array(periodsdev, 'float')
fitperiods = periodsdev * periods + periods

periodi, periodsdevi, counts = count_number(periods, periodsdev, nxbins=100, nybins=100)
plt.figure()
levels = np.arange(0, 15, .1)
#levels = np.log10(levels)
#counts = np.log10(counts)
plt.contourf(periodi, periodsdevi, counts, levels, extend='max')
cbar = plt.colorbar()
cbar.set_label('logN')
plt.xlabel('Period (days)')
plt.ylabel('Period deviation')


plt.figure()
plt.plot(periods, fitperiods, 'k.')
plt.xlabel('True Period (days)')
plt.ylabel('Fit Period (days)')

periodi, fitperiodsi, counts = count_number(periods, fitperiods, nxbins=100, nybins=100)
plt.figure()
#counts = np.log10(counts)
plt.contourf(periodi, fitperiodsi, counts, levels, extend='max')
cbar = plt.colorbar()
cbar.set_label('logN')
plt.xlabel('True Period (days)')
plt.ylabel('Fit period (days)')
